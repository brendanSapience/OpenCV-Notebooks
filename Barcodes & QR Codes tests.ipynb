# %% [markdown]
# # QR and Barcode Tests with zbar

# %% [markdown]
# ####  QR Barcodes: Work OK

# %% [markdown]
# ![SetDataQRCode.png](attachment:SetDataQRCode.png)

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decode(Image.open('./inputs/barcodes/QRCodeExample.png'))
# Out:
# [Decoded(data=b'Antenna House Inc., 3844 Kennett Pike Suite 200 Greenville, Delaware 19807 USA http://www.antennahouse.com', type='QRCODE', rect=Rect(left=535, top=157, width=112, height=112), polygon=[Point(x=535, y=157), Point(x=535, y=268), Point(x=647, y=269), Point(x=646, y=157)])]

# %% [markdown]
# ####  Micor QR Barcodes: does NOT work

# %% [markdown]
# ![QRCodeExample2.png](attachment:QRCodeExample2.png)

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decode(Image.open('./inputs/barcodes/QRCodeExample2.png'))
# Out:
# []

# %% [markdown]
# ####  EAN/JAN Barcodes: works well

# %% [markdown]
# ![BarCodeExample.png](attachment:BarCodeExample.png)

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decode(Image.open('./inputs/barcodes/BarCodeExample.png'))
# Out:
# [Decoded(data=b'4901234567894', type='EAN13', rect=Rect(left=955, top=92, width=107, height=148), polygon=[Point(x=955, y=93), Point(x=955, y=239), Point(x=1062, y=240), Point(x=1062, y=92), Point(x=961, y=92)])]

# %% [markdown]
# ####  POSTNET Barcodes: Does not work

# %% [markdown]
# ![IMBCBarCodeExample.png](attachment:IMBCBarCodeExample.png)

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decode(Image.open('./inputs/barcodes/IMBCBarCodeExample.png'))
# Out:
# []
